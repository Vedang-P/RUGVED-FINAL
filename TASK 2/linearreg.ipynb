# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd

# %%
df=pd.read_csv('co2.csv')
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244

# %%
# Select features and target
features = ['Engine Size(L)', 'Cylinders', 'Fuel Consumption Comb (L/100 km)']
target = 'CO2 Emissions(g/km)'

X = df[features].values  # shape: (n_samples, n_features)
y = df[target].values.reshape(-1, 1)  # shape: (n_samples, 1)

# %%
# Standardize the features (mean 0, std 1)
X_mean = X.mean(axis=0)
X_std = X.std(axis=0)
X = (X - X_mean) / X_std

# %%
# Set random seed for reproducibility
np.random.seed(20)

n_samples, n_features = X.shape
W = np.random.randn(n_features, 1)  # weights
b = np.zeros((1,))                 # bias

# %%
def predict(X, W, b):
    return np.dot(X, W) + b

# %%
def compute_loss(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
def compute_gradients(X, y_true, y_pred):
    n = X.shape[0]
    dW = (-2/n) * np.dot(X.T, (y_true - y_pred))
    db = (-2/n) * np.sum(y_true - y_pred)
    return dW, db

# %%
learning_rate = 0.01
n_epochs = 1000

loss_history = []

for epoch in range(n_epochs):
    y_pred = predict(X, W, b)
    loss = compute_loss(y, y_pred)
    dW, db = compute_gradients(X, y, y_pred)
    
    # Update weights
    W -= learning_rate * dW
    b -= learning_rate * db
    
    loss_history.append(loss)
    
    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Loss = {loss:}")
# Out:
# Epoch 0: Loss = 66111.3247
# Epoch 100: Loss = 1569.8445
# Epoch 200: Loss = 453.2558
# Epoch 300: Loss = 422.1490
# Epoch 400: Loss = 417.1523
# Epoch 500: Loss = 415.2790
# Epoch 600: Loss = 414.4863
# Epoch 700: Loss = 414.1187
# Epoch 800: Loss = 413.9272
# Epoch 900: Loss = 413.8148

# %%
plt.plot(loss_history)
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.show()

# %%
learning_rate = 0.01
n_epochs = 10000

loss_history = []

for epoch in range(n_epochs):
    y_pred = predict(X, W, b)
    loss = compute_loss(y, y_pred)
    dW, db = compute_gradients(X, y, y_pred)
    
    # Update weights
    W -= learning_rate * dW
    b -= learning_rate * db
    
    loss_history.append(loss)
    
    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Loss = {loss:}")
# Out:
# Epoch 0: Loss = 413.7419
# Epoch 100: Loss = 413.6912
# Epoch 200: Loss = 413.6545
# Epoch 300: Loss = 413.6274
# Epoch 400: Loss = 413.6072
# Epoch 500: Loss = 413.5919
# Epoch 600: Loss = 413.5804
# Epoch 700: Loss = 413.5717
# Epoch 800: Loss = 413.5651
# Epoch 900: Loss = 413.5601
# Epoch 1000: Loss = 413.5564
# Epoch 1100: Loss = 413.5535
# Epoch 1200: Loss = 413.5514
# Epoch 1300: Loss = 413.5497
# Epoch 1400: Loss = 413.5485
# Epoch 1500: Loss = 413.5476
# Epoch 1600: Loss = 413.5468
# Epoch 1700: Loss = 413.5463
# Epoch 1800: Loss = 413.5459
# Epoch 1900: Loss = 413.5456
# Epoch 2000: Loss = 413.5454
# Epoch 2100: Loss = 413.5452
# Epoch 2200: Loss = 413.5451
# Epoch 2300: Loss = 413.5450
# Epoch 2400: Loss = 413.5449
# Epoch 2500: Loss = 413.5448
# Epoch 2600: Loss = 413.5448
# Epoch 2700: Loss = 413.5447
# Epoch 2800: Loss = 413.5447
# Epoch 2900: Loss = 413.5447
# Epoch 3000: Loss = 413.5447
# Epoch 3100: Loss = 413.5447
# Epoch 3200: Loss = 413.5447
# Epoch 3300: Loss = 413.5447
# Epoch 3400: Loss = 413.5447
# Epoch 3500: Loss = 413.5447
# Epoch 3600: Loss = 413.5447
# Epoch 3700: Loss = 413.5447
# Epoch 3800: Loss = 413.5447
# Epoch 3900: Loss = 413.5447
# Epoch 4000: Loss = 413.5446
# Epoch 4100: Loss = 413.5446
# Epoch 4200: Loss = 413.5446
# Epoch 4300: Loss = 413.5446
# Epoch 4400: Loss = 413.5446
# Epoch 4500: Loss = 413.5446
# Epoch 4600: Loss = 413.5446
# Epoch 4700: Loss = 413.5446
# Epoch 4800: Loss = 413.5446
# Epoch 4900: Loss = 413.5446
# Epoch 5000: Loss = 413.5446
# Epoch 5100: Loss = 413.5446
# Epoch 5200: Loss = 413.5446
# Epoch 5300: Loss = 413.5446
# Epoch 5400: Loss = 413.5446
# Epoch 5500: Loss = 413.5446
# Epoch 5600: Loss = 413.5446
# Epoch 5700: Loss = 413.5446
# Epoch 5800: Loss = 413.5446
# Epoch 5900: Loss = 413.5446
# Epoch 6000: Loss = 413.5446
# Epoch 6100: Loss = 413.5446
# Epoch 6200: Loss = 413.5446
# Epoch 6300: Loss = 413.5446
# Epoch 6400: Loss = 413.5446
# Epoch 6500: Loss = 413.5446
# Epoch 6600: Loss = 413.5446
# Epoch 6700: Loss = 413.5446
# Epoch 6800: Loss = 413.5446
# Epoch 6900: Loss = 413.5446
# Epoch 7000: Loss = 413.5446
# Epoch 7100: Loss = 413.5446
# Epoch 7200: Loss = 413.5446
# Epoch 7300: Loss = 413.5446
# Epoch 7400: Loss = 413.5446
# Epoch 7500: Loss = 413.5446
# Epoch 7600: Loss = 413.5446
# Epoch 7700: Loss = 413.5446
# Epoch 7800: Loss = 413.5446
# Epoch 7900: Loss = 413.5446
# Epoch 8000: Loss = 413.5446
# Epoch 8100: Loss = 413.5446
# Epoch 8200: Loss = 413.5446
# Epoch 8300: Loss = 413.5446
# Epoch 8400: Loss = 413.5446
# Epoch 8500: Loss = 413.5446
# Epoch 8600: Loss = 413.5446
# Epoch 8700: Loss = 413.5446
# Epoch 8800: Loss = 413.5446
# Epoch 8900: Loss = 413.5446
# Epoch 9000: Loss = 413.5446
# Epoch 9100: Loss = 413.5446
# Epoch 9200: Loss = 413.5446
# Epoch 9300: Loss = 413.5446
# Epoch 9400: Loss = 413.5446
# Epoch 9500: Loss = 413.5446
# Epoch 9600: Loss = 413.5446
# Epoch 9700: Loss = 413.5446
# Epoch 9800: Loss = 413.5446
# Epoch 9900: Loss = 413.5446
